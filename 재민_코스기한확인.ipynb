# %%
import pandas as pd

df = pd.read_csv("Courses.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641138 entries, 0 to 641137
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              641138 non-null  int64
#  1   course_id          641138 non-null  object
#  2   userid_DI          641138 non-null  object
#  3   registered         641138 non-null  int64
#  4   viewed             641138 non-null  int64
#  5   explored           641138 non-null  int64
#  6   certified          641138 non-null  int64
#  7   final_cc_cname_DI  641138 non-null  object
#  8   LoE_DI             535130 non-null  object
#  9   YoB                544533 non-null  float64
#  10  gender             554332 non-null  object
#  11  grade              592766 non-null  object
#  12  start_time_DI      641138 non-null  object
#  13  last_event_DI      462184 non-null  object
#  14  nevents            441987 non-null  float64
# ...

# %%
df['course_id'].unique()
# Out:
# array(['HarvardX/CB22x/2013_Spring', 'HarvardX/CS50x/2012',
#        'HarvardX/ER22x/2013_Spring', 'HarvardX/PH207x/2012_Fall',
#        'HarvardX/PH278x/2013_Spring', 'MITx/6.002x/2012_Fall',
#        'MITx/6.002x/2013_Spring', 'MITx/14.73x/2013_Spring',
#        'MITx/2.01x/2013_Spring', 'MITx/3.091x/2012_Fall',
#        'MITx/3.091x/2013_Spring', 'MITx/6.00x/2012_Fall',
#        'MITx/6.00x/2013_Spring', 'MITx/7.00x/2013_Spring',
#        'MITx/8.02x/2013_Spring', 'MITx/8.MReV/2013_Summer'], dtype=object)

# %%
df['last_event_DI'] = pd.to_datetime(df['last_event_DI'])

# %% [markdown]
# ### HarvardX/CB22x/2013_Spring

# %%
df1 = df.loc[
    (df['course_id'] == 'HarvardX/CB22x/2013_Spring')
    & (df['last_event_DI'] > '2013-08-26') 
]

len(df1['last_event_DI'])
# Out:
# 8261

# %% [markdown]
# ### HarvardX/ER22x/2013_Spring

# %%
df2 = df.loc[
    (df['course_id'] == 'HarvardX/ER22x/2013_Spring')
    & (df['last_event_DI'] > '2013-07-26') 
]

len(df2['last_event_DI'])
# Out:
# 8604

# %% [markdown]
# ### HarvardX/PH207x/2012_Fall

# %%
df3 = df.loc[
    (df['course_id'] == 'HarvardX/PH207x/2012_Fall')
    & (df['last_event_DI'] > '2013-01-30') 
]

len(df3['last_event_DI'])
# Out:
# 8212

# %% [markdown]
# ### HarvardX/PH278x/2013_Spring

# %%
df4 = df.loc[
    (df['course_id'] == 'HarvardX/PH278x/2013_Spring')
    & (df['last_event_DI'] > '2013-07-25') 
]

len(df4['last_event_DI'])
# Out:
# 3320

# %% [markdown]
# ### MITx/6.002x/2012_Fall

# %%
df5 = df.loc[
    (df['course_id'] == 'MITx/6.002x/2012_Fall')
    & (df['last_event_DI'] > '2012-12-25') 
]

len(df5['last_event_DI'])
# Out:
# 13323

# %% [markdown]
# ### MITx/6.002x/2013_Spring

# %%
df6 = df.loc[
    (df['course_id'] == 'MITx/6.002x/2013_Spring')
    & (df['last_event_DI'] > '2013-07-13') 
]

len(df6['last_event_DI'])
# Out:
# 4717

# %% [markdown]
# ### MITx/14.73x/2013_Spring

# %%
df7 = df.loc[
    (df['course_id'] == 'MITx/14.73x/2013_Spring')
    & (df['last_event_DI'] > '2013-03-13') 
]

len(df7['last_event_DI'])
# Out:
# 10579

# %% [markdown]
# ### MITx/2.01x/2013_Spring

# %%
df8 = df.loc[
    (df['course_id'] == 'MITx/2.01x/2013_Spring')
    & (df['last_event_DI'] > '2013-07-30') 
]

len(df8['last_event_DI'])
# Out:
# 596

# %% [markdown]
# ### MITx/3.091x/2012_Fall

# %%
df9 = df.loc[
    (df['course_id'] == 'MITx/3.091x/2012_Fall')
    & (df['last_event_DI'] > '2013-01-15') 
]

len(df9['last_event_DI'])
# Out:
# 1697

# %% [markdown]
# ### MITx/3.091x/2013_Spring

# %%
df10 = df.loc[
    (df['course_id'] == 'MITx/3.091x/2013_Spring')
    & (df['last_event_DI'] > '2013-06-21') 
]

len(df10['last_event_DI'])
# Out:
# 1053

# %% [markdown]
# ### MITx/6.00x/2012_Fall

# %%
df11 = df.loc[
    (df['course_id'] == 'MITx/6.00x/2012_Fall')
    & (df['last_event_DI'] > '2013-01-15') 
]

len(df11['last_event_DI'])
# Out:
# 8910

# %% [markdown]
# ### MITx/6.00x/2013_Spring

# %%
df12 = df.loc[
    (df['course_id'] == 'MITx/6.00x/2012_Spring')
    & (df['last_event_DI'] > '2013-06-04') 
]

len(df12['last_event_DI'])
# Out:
# 0

# %% [markdown]
# ### MITx/7.00x/2013_Spring

# %%
df13 = df.loc[
    (df['course_id'] == 'MITx/7.00x/2013_Spring')
    & (df['last_event_DI'] > '2013-06-13') 
]

len(df13['last_event_DI'])
# Out:
# 2399

# %% [markdown]
# ### MITx/8.02x/2013_Spring

# %%
df14 = df.loc[
    (df['course_id'] == 'MITx/8.02x/2013_Spring')
    & (df['last_event_DI'] > '2013-06-18') 
]

len(df14['last_event_DI'])
# Out:
# 5272

# %% [markdown]
# ### MITx/8.MReV/2013_Summer

# %%
df15 = df.loc[
    (df['course_id'] == 'MITx/8.MReV/2013_Summer')
    & (df['last_event_DI'] > '2013-09-15') 
]

len(df15['last_event_DI'])
# Out:
# 0

# %%
result = 0

for i in range(1, 16):
    name = f'df{i}'
    if name in globals():
        result += len(globals()[name]['last_event_DI'])

print(result)
# Out:
# 641138
# 76943

# %%
import pandas as pd

# 1. 생성하신 변수들을 리스트로 묶습니다.
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]

def summarize_late_data(dfs):
    summary_list = []
    
    for i, tmp_df in enumerate(dfs, 1):
        if not tmp_df.empty:
            # 해당 강의의 ID (첫 번째 행 기준)
            c_id = tmp_df['course_id'].iloc[0]
            # 활동 인원 수
            count = len(tmp_df)
            # 가장 마지막 활동일 (이상치 확인용)
            max_date = tmp_df['last_event_DI'].max()
            
            summary_list.append({
                'No': f'df{i}',
                'Course_ID': c_id,
                'Late_Users': count,
                'Max_Last_Event': max_date
            })
        else:
            summary_list.append({
                'No': f'df{i}',
                'Course_ID': 'No Data',
                'Late_Users': 0,
                'Max_Last_Event': None
            })
            
    return pd.DataFrame(summary_list)

# 실행 및 결과 확인
report_df = summarize_late_data(df_list)
print(report_df)
# Out:
#       No                    Course_ID  Late_Users Max_Last_Event
# 0    df1   HarvardX/CB22x/2013_Spring        8261     2013-11-17
# 1    df2   HarvardX/ER22x/2013_Spring        8604     2013-09-07
# 2    df3    HarvardX/PH207x/2012_Fall        8212     2013-09-07
# 3    df4  HarvardX/PH278x/2013_Spring        3320     2013-09-07
# 4    df5        MITx/6.002x/2012_Fall       13323     2013-09-07
# 5    df6      MITx/6.002x/2013_Spring        4717     2013-09-07
# 6    df7      MITx/14.73x/2013_Spring       10579     2013-09-07
# 7    df8       MITx/2.01x/2013_Spring         596     2013-09-07
# 8    df9        MITx/3.091x/2012_Fall        1697     2013-09-07
# 9   df10      MITx/3.091x/2013_Spring        1053     2013-09-07
# 10  df11         MITx/6.00x/2012_Fall        8910     2013-09-07
# 11  df12                      No Data           0            NaT
# 12  df13       MITx/7.00x/2013_Spring        2399     2013-09-07
# ...

# %%
# 전체 강의 리스트 (df1 ~ df15가 각각의 추출본이라고 가정)
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]

# 시각화 설정 (3행 5열)
fig, axes = plt.subplots(3, 5, figsize=(20, 12), sharex=True)
axes = axes.flatten()

for i, tmp_df in enumerate(df_list):
    if not tmp_df.empty:
        # 각 df 내에 실제 종료일 컬럼이 있다면 사용, 없다면 필터 기준일 사용
        # 여기서는 예시로 각 df의 최소 날짜를 기준으로 '경과일' 계산
        # (실제 분석 시에는 각 강의의 실제 종료일을 빼주세요)
        start_ref = pd.to_datetime(tmp_df['last_event_DI']).min() 
        days = (pd.to_datetime(tmp_df['last_event_DI']) - start_ref).dt.days
        
        sns.histplot(days, bins=15, ax=axes[i], kde=True, color='skyblue')
        axes[i].set_title(f'df{i+1} 활동 분포')
        axes[i].set_xlabel('Days After')
    else:
        axes[i].set_title(f'df{i+1} (데이터 없음)')

plt.tight_layout()
plt.show()
